# %% [markdown]
# # Notes
#
# This notebook is for inference and visualizations.
#
# You can either load images from a dataloader(see Sec. 1) or from a local path(see Sec. 2).

# %%
import os, sys
import json
import numpy as np
import mlx.core as mx
from main import build_model_main
from util.slconfig import SLConfig
from datasets import build_dataset
from util.visualizer import COCOVisualizer
from util import box_ops
import util.misc as utils
from pprint import pprint

# %% [markdown]
# # Initialize and Load Pre-trained Models

# %%
model_config_path = "config/DINO/DINO_4scale.py" # change the path of the model config file

# %%
args = SLConfig.fromfile(model_config_path) 
args.device = 'metal' 
model, criterion, postprocessors = build_model_main(args)
model = utils.load_mlx_model_with_pytorch_weights(model, args.pytorch_weights_path, None)
model.eval()
# Out:
# /Users/sachinraja/Code/DINO_DETR_MLX/util/pytorch_weights_to_mlx.py:154: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pytorch_weights_flattened = torch.load(
# DINO(
#   (transformer): DeformableTransformer(
#     (encoder): TransformerEncoder(
#       (params.encoder_layer): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.0): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.1): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.2): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.3): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.4): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.5): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#     )
#     (decoder): TransformerDecoder(
#       (params.decoder_layer): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (params.norm): LayerNorm(256, eps=1e-05, affine=True)
#       (layers.0): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.1): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.2): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.3): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.4): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.5): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (norm): LayerNorm(256, eps=1e-05, affine=True)
#       (ref_point_head): MLP(
#         (layers.0): Linear(input_dims=512, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#       )
#       (bbox_embed.0): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.1): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.2): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.3): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.4): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.5): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (class_embed.0): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.1): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.2): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.3): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.4): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.5): Linear(input_dims=256, output_dims=91, bias=True)
#     )
#     (tgt_embed): Embedding(900, 256)
#     (enc_output): Linear(input_dims=256, output_dims=256, bias=True)
#     (enc_output_norm): LayerNorm(256, eps=1e-05, affine=True)
#     (enc_out_bbox_embed): MLP(
#       (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#       (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#       (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#     )
#     (enc_out_class_embed): Linear(input_dims=256, output_dims=91, bias=True)
#   )
#   (label_enc): Embedding(92, 256)
#   (dn_encoder): DNEncoder(
#     (label_enc): Embedding(92, 256)
#   )
#   (input_proj.0): Sequential(
#     (layers.0): Conv2d(512, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=True)
#     (layers.1): GroupNorm(32, 256, eps=1e-05, affine=True, pytorch_compatible=False)
#   )
#   (input_proj.1): Sequential(
#     (layers.0): Conv2d(1024, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=True)
#     (layers.1): GroupNorm(32, 256, eps=1e-05, affine=True, pytorch_compatible=False)
#   )
#   (input_proj.2): Sequential(
#     (layers.0): Conv2d(2048, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=True)
#     (layers.1): GroupNorm(32, 256, eps=1e-05, affine=True, pytorch_compatible=False)
#   )
#   (input_proj.3): Sequential(
#     (layers.0): Conv2d(2048, 256, kernel_size=(3,), stride=(2, 2), padding=(1, 1), dilation=1, bias=True)
#     (layers.1): GroupNorm(32, 256, eps=1e-05, affine=True, pytorch_compatible=False)
#   )
#   (backbone): Joiner(
#     (layers.0): Backbone(
#       (body): ResNet(
#         (conv1): Conv2d(3, 64, kernel_size=(7,), stride=(2, 2), padding=(3, 3), dilation=1, bias=False)
#         (bn1): FrozenBatchNorm2d()
#         (relu): ReLU()
#         (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (layer1): Sequential(
#           (layers.0): Bottleneck(
#             (conv1): Conv2d(64, 64, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#             (downsample): Sequential(
#               (layers.0): Conv2d(64, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#               (layers.1): FrozenBatchNorm2d()
#             )
#           )
#           (layers.1): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#           (layers.2): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#         )
#         (layer2): Sequential(
#           (layers.0): Bottleneck(
#             (conv1): Conv2d(256, 128, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3,), stride=(2, 2), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#             (downsample): Sequential(
#               (layers.0): Conv2d(256, 512, kernel_size=(1,), stride=(2, 2), padding=(0, 0), dilation=1, bias=False)
#               (layers.1): FrozenBatchNorm2d()
#             )
#           )
#           (layers.1): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#           (layers.2): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#           (layers.3): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#         )
#         (layer3): Sequential(
#           (layers.0): Bottleneck(
#             (conv1): Conv2d(512, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3,), stride=(2, 2), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#             (downsample): Sequential(
#               (layers.0): Conv2d(512, 1024, kernel_size=(1,), stride=(2, 2), padding=(0, 0), dilation=1, bias=False)
#               (layers.1): FrozenBatchNorm2d()
#             )
#           )
#           (layers.1): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#           (layers.2): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#           (layers.3): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#           (layers.4): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#           (layers.5): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#         )
#         (layer4): Sequential(
#           (layers.0): Bottleneck(
#             (conv1): Conv2d(1024, 512, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3,), stride=(2, 2), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#             (downsample): Sequential(
#               (layers.0): Conv2d(1024, 2048, kernel_size=(1,), stride=(2, 2), padding=(0, 0), dilation=1, bias=False)
#               (layers.1): FrozenBatchNorm2d()
#             )
#           )
#           (layers.1): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#           (layers.2): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3,), stride=(1, 1), padding=(1, 1), dilation=1, bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU()
#           )
#         )
#         (avgpool): AdaptiveAveragePool2D()
#         (fc): Linear(input_dims=2048, output_dims=1000, bias=True)
#       )
#     )
#     (layers.1): PositionEmbeddingSine()
#   )
#   (bbox_embed.0): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.1): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.2): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.3): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.4): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.5): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (class_embed.0): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.1): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.2): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.3): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.4): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.5): Linear(input_dims=256, output_dims=91, bias=True)
# )

# %%
# load coco names
with open('util/coco_id2name.json') as f:
    id2name = json.load(f)
    id2name = {int(k):v for k,v in id2name.items()}

# %% [markdown]
# # Visualize Custom Images

# %%
from PIL import Image
import datasets.transforms as T

# %%
image = Image.open("./figs/idea.jpg").convert("RGB") # load image

# %%
# transform images
transform = T.Compose([
    T.RandomResize([800], max_size=1333),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
image, _ = transform(image, None)
image = mx.array(image.numpy()).transpose(1, 2, 0)

# %%
print(image.shape)
# Out:
# (1199, 800, 3)

# %%
# predict images
output = model(image[None])
output = postprocessors['bbox'](output, mx.array([[1.0, 1.0]]))[0]

# %%
pprint(output)
# Out:
# {'boxes': array([[0.754515, 0.638549, 0.999951, 0.889742],
#        [0.751854, 0.300897, 0.999526, 0.540114],
#        [0.222147, 0.441283, 0.43259, 0.79002],
#        ...,
#        [0.249086, 0.600319, 0.433076, 0.700595],
#        [0.304716, 0.557693, 0.597626, 0.646513],
#        [0.979871, 0.548926, 1, 0.559701]], dtype=float32),
#  'labels': array([62, 72, 62, ..., 62, 62, 84], dtype=uint32),
#  'scores': array([0.89, 0.74588, 0.714099, ..., 0.022895, 0.0228821, 0.0228176], dtype=float32)}

# %%
# visualize outputs
thershold = 0.3 # set a thershold

vslzr = COCOVisualizer()

scores = output['scores']
labels = output['labels']
boxes = box_ops.box_xyxy_to_cxcywh(output['boxes'])
select_mask = scores > thershold
labels = np.asarray(labels)
boxes = np.asarray(boxes)
select_mask = np.asarray(select_mask)
# image = np.asarray(image)
print(image.shape)
box_label = [id2name[int(item)] for item in labels[select_mask]]
pred_dict = {
    'boxes': boxes[select_mask],
    'size': mx.array([image.shape[0], image.shape[1]]),
    'box_label': box_label
}
vslzr.visualize(image, pred_dict, savedir=None, dpi=100)
# Out:
# (1199, 800, 3)
