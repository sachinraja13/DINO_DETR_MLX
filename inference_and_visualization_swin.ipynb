# %% [markdown]
# # Notes
#
# This notebook is for inference and visualizations.
#
# You can either load images from a dataloader(see Sec. 1) or from a local path(see Sec. 2).

# %%
import os, sys
import json
import numpy as np
import mlx.core as mx
from main import build_model_main
from util.slconfig import SLConfig
from datasets import build_dataset
from util.visualizer import COCOVisualizer
from util import box_ops
import util.misc as utils
from pprint import pprint

# %% [markdown]
# # Initialize and Load Pre-trained Models

# %%
model_config_path = "config/DINO/DINO_4scale_swin.py" # change the path of the model config file

# %%
args = SLConfig.fromfile(model_config_path) 
args.device = 'metal' 
model, criterion, postprocessors = build_model_main(args)
model = utils.load_mlx_model_with_pytorch_weights(model, args.pytorch_weights_path, args.backbone, None)
model.eval()
# Out:
# /Users/sachinraja/Code/DINO_DETR_MLX/util/pytorch_weights_to_mlx.py:198: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pytorch_weights_flattened = torch.load(
# DINO(
#   (transformer): DeformableTransformer(
#     (encoder): TransformerEncoder(
#       (params.encoder_layer): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.0): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.1): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.2): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.3): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.4): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.5): DeformableTransformerEncoderLayer(
#         (self_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout2): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#       )
#     )
#     (decoder): TransformerDecoder(
#       (params.decoder_layer): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (params.norm): LayerNorm(256, eps=1e-05, affine=True)
#       (layers.0): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.1): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.2): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.3): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.4): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (layers.5): DeformableTransformerDecoderLayer(
#         (cross_attn): MSDeformAttn(
#           (sampling_offsets): Linear(input_dims=256, output_dims=256, bias=True)
#           (attention_weights): Linear(input_dims=256, output_dims=128, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (output_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout1): Dropout(p=0.0)
#         (norm1): LayerNorm(256, eps=1e-05, affine=True)
#         (self_attn): MultiHeadAttention(
#           (query_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (key_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (value_proj): Linear(input_dims=256, output_dims=256, bias=True)
#           (out_proj): Linear(input_dims=256, output_dims=256, bias=True)
#         )
#         (dropout2): Dropout(p=0.0)
#         (norm2): LayerNorm(256, eps=1e-05, affine=True)
#         (linear1): Linear(input_dims=256, output_dims=2048, bias=True)
#         (dropout3): Dropout(p=0.0)
#         (linear2): Linear(input_dims=2048, output_dims=256, bias=True)
#         (dropout4): Dropout(p=0.0)
#         (norm3): LayerNorm(256, eps=1e-05, affine=True)
#       )
#       (norm): LayerNorm(256, eps=1e-05, affine=True)
#       (ref_point_head): MLP(
#         (layers.0): Linear(input_dims=512, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#       )
#       (bbox_embed.0): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.1): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.2): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.3): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.4): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (bbox_embed.5): MLP(
#         (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#         (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#       )
#       (class_embed.0): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.1): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.2): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.3): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.4): Linear(input_dims=256, output_dims=91, bias=True)
#       (class_embed.5): Linear(input_dims=256, output_dims=91, bias=True)
#     )
#     (tgt_embed): Embedding(900, 256)
#     (enc_output): Linear(input_dims=256, output_dims=256, bias=True)
#     (enc_output_norm): LayerNorm(256, eps=1e-05, affine=True)
#     (enc_out_bbox_embed): MLP(
#       (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#       (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#       (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#     )
#     (enc_out_class_embed): Linear(input_dims=256, output_dims=91, bias=True)
#   )
#   (label_enc): Embedding(92, 256)
#   (dn_encoder): DNEncoder(
#     (label_enc): Embedding(92, 256)
#   )
#   (input_proj.0): Sequential(
#     (layers.0): Conv2d(384, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=True)
#     (layers.1): GroupNorm(32, 256, eps=1e-05, affine=True, pytorch_compatible=False)
#   )
#   (input_proj.1): Sequential(
#     (layers.0): Conv2d(768, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=True)
#     (layers.1): GroupNorm(32, 256, eps=1e-05, affine=True, pytorch_compatible=False)
#   )
#   (input_proj.2): Sequential(
#     (layers.0): Conv2d(1536, 256, kernel_size=(1,), stride=(1, 1), padding=(0, 0), dilation=1, bias=True)
#     (layers.1): GroupNorm(32, 256, eps=1e-05, affine=True, pytorch_compatible=False)
#   )
#   (input_proj.3): Sequential(
#     (layers.0): Conv2d(1536, 256, kernel_size=(3,), stride=(2, 2), padding=(1, 1), dilation=1, bias=True)
#     (layers.1): GroupNorm(32, 256, eps=1e-05, affine=True, pytorch_compatible=False)
#   )
#   (backbone): Joiner(
#     (layers.0): Backbone(
#       (body): SwinTransformer(
#         (patch_embed): Sequential(
#           (layers.0): Conv2d(3, 192, kernel_size=(4,), stride=(4, 4), padding=(0, 0), dilation=1, bias=True)
#           (layers.1): Identity()
#           (layers.2): LayerNorm(192, eps=1e-05, affine=True)
#         )
#         (layers.0): Sequential(
#           (layers.0): SwinTransformerBlock(
#             (norm1): LayerNorm(192, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=192, output_dims=576, bias=True)
#               (proj): Linear(input_dims=192, output_dims=192, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(192, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=192, output_dims=768, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=768, output_dims=192, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.1): SwinTransformerBlock(
#             (norm1): LayerNorm(192, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=192, output_dims=576, bias=True)
#               (proj): Linear(input_dims=192, output_dims=192, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(192, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=192, output_dims=768, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=768, output_dims=192, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#         )
#         (layers.1): PatchMerging(
#           (reduction): Linear(input_dims=768, output_dims=384, bias=False)
#           (norm): LayerNorm(768, eps=1e-05, affine=True)
#         )
#         (layers.2): Sequential(
#           (layers.0): SwinTransformerBlock(
#             (norm1): LayerNorm(384, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=384, output_dims=1152, bias=True)
#               (proj): Linear(input_dims=384, output_dims=384, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(384, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=384, output_dims=1536, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=1536, output_dims=384, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.1): SwinTransformerBlock(
#             (norm1): LayerNorm(384, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=384, output_dims=1152, bias=True)
#               (proj): Linear(input_dims=384, output_dims=384, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(384, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=384, output_dims=1536, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=1536, output_dims=384, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#         )
#         (layers.3): PatchMerging(
#           (reduction): Linear(input_dims=1536, output_dims=768, bias=False)
#           (norm): LayerNorm(1536, eps=1e-05, affine=True)
#         )
#         (layers.4): Sequential(
#           (layers.0): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.1): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.2): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.3): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.4): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.5): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.6): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.7): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.8): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.9): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.10): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.11): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.12): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.13): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.14): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.15): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.16): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.17): SwinTransformerBlock(
#             (norm1): LayerNorm(768, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=768, output_dims=2304, bias=True)
#               (proj): Linear(input_dims=768, output_dims=768, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(768, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=768, output_dims=3072, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=3072, output_dims=768, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#         )
#         (layers.5): PatchMerging(
#           (reduction): Linear(input_dims=3072, output_dims=1536, bias=False)
#           (norm): LayerNorm(3072, eps=1e-05, affine=True)
#         )
#         (layers.6): Sequential(
#           (layers.0): SwinTransformerBlock(
#             (norm1): LayerNorm(1536, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=1536, output_dims=4608, bias=True)
#               (proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(1536, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=1536, output_dims=6144, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=6144, output_dims=1536, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#           (layers.1): SwinTransformerBlock(
#             (norm1): LayerNorm(1536, eps=1e-05, affine=True)
#             (attn): ShiftedWindowAttention(
#               (qkv): Linear(input_dims=1536, output_dims=4608, bias=True)
#               (proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#             )
#             (stochastic_depth): StochasticDepth()
#             (norm2): LayerNorm(1536, eps=1e-05, affine=True)
#             (mlp): MLP(
#               (layers.0): Linear(input_dims=1536, output_dims=6144, bias=True)
#               (layers.1): GELU()
#               (layers.2): Dropout(p=0.0)
#               (layers.3): Linear(input_dims=6144, output_dims=1536, bias=True)
#               (layers.4): Dropout(p=0.0)
#             )
#           )
#         )
#         (norm): LayerNorm(1536, eps=1e-05, affine=True)
#         (avgpool): AdaptiveAvgPool2d()
#         (norm_layers.0): LayerNorm(384, eps=1e-05, affine=True)
#         (norm_layers.1): LayerNorm(768, eps=1e-05, affine=True)
#         (norm_layers.2): LayerNorm(1536, eps=1e-05, affine=True)
#         (head): Linear(input_dims=1536, output_dims=1000, bias=True)
#       )
#     )
#     (layers.1): PositionEmbeddingSine()
#   )
#   (bbox_embed.0): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.1): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.2): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.3): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.4): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (bbox_embed.5): MLP(
#     (layers.0): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.1): Linear(input_dims=256, output_dims=256, bias=True)
#     (layers.2): Linear(input_dims=256, output_dims=4, bias=True)
#   )
#   (class_embed.0): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.1): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.2): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.3): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.4): Linear(input_dims=256, output_dims=91, bias=True)
#   (class_embed.5): Linear(input_dims=256, output_dims=91, bias=True)
# )

# %%
# load coco names
with open('util/coco_id2name.json') as f:
    id2name = json.load(f)
    id2name = {int(k):v for k,v in id2name.items()}

# %% [markdown]
# # Visualize Custom Images

# %%
from PIL import Image
import datasets.transforms as T

# %%
image = Image.open("./figs/idea.jpg").convert("RGB") # load image

# %%
# transform images
transform = T.Compose([
    T.RandomResize([800], max_size=1333),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
image, _ = transform(image, None)
image = mx.array(image.numpy()).transpose(1, 2, 0)

# %%
print(image.shape)
# Out:
# (1199, 800, 3)

# %%
# predict images
output = model(image[None])
output = postprocessors['bbox'](output, mx.array([[1.0, 1.0]]))[0]

# %%
pprint(output)
# Out:
# {'boxes': array([[0.753456, 0.300464, 0.99937, 0.497483],
#        [0.74538, 0.646396, 1, 0.885837],
#        [0.382414, 0.3095, 0.748125, 0.577949],
#        ...,
#        [0.81931, 0.527312, 0.946801, 0.561951],
#        [0.304267, 0.564361, 0.499272, 0.648051],
#        [0.42822, 0.482882, 0.533913, 0.577725]], dtype=float32),
#  'labels': array([72, 62, 64, ..., 84, 2, 64], dtype=uint32),
#  'scores': array([0.844652, 0.799851, 0.77425, ..., 0.0219006, 0.0218595, 0.0218471], dtype=float32)}

# %%
# visualize outputs
thershold = 0.3 # set a thershold

vslzr = COCOVisualizer()

scores = output['scores']
labels = output['labels']
boxes = box_ops.box_xyxy_to_cxcywh(output['boxes'])
select_mask = scores > thershold
labels = np.asarray(labels)
boxes = np.asarray(boxes)
select_mask = np.asarray(select_mask)
# image = np.asarray(image)
print(image.shape)
box_label = [id2name[int(item)] for item in labels[select_mask]]
pred_dict = {
    'boxes': boxes[select_mask],
    'size': mx.array([image.shape[0], image.shape[1]]),
    'box_label': box_label
}
vslzr.visualize(image, pred_dict, savedir=None, dpi=100)
# Out:
# (1199, 800, 3)
